# %%
print("hello")

# !wget --no-check-certificate https://cvrr-nas.ucsd.edu/LISA/Datasets/signDatabasePublicFramesOnly.zip
"""
Setting work environment with dataset. If on Google colaboratory, we need to extract dataset stored in google drive,
otherwise the dataset is already there.
"""
try:
    from google.colab import drive
    print('Running on Google colab...')
    drive.mount('/content/drive')
    from zipfile import Zipfile
    # /content/signDatabasePublicFramesOnly.zip
    # !cp '/content/drive/MyDrive/Colab Notebooks/DL-Project/signDatabasePublicFramesOnly.zip' dataset.zip

    # with ZipFile('/content/drive/MyDrive/Colab Notebooks/DL-Project/signDatabasePublicFramesOnly.zip', 'r') as zip_ref:
    #     zip_ref.extractall('test')
except:
    print('Running on local machine...')
# Out:
# hello
# Running on Google colab...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Running on local machine...

# %%
# GET /test
print("hello")

# %%
# !ls
# !cp '/content/drive/MyDrive/Colab Notebooks/DL-Project/signDatabasePublicFramesOnly.zip' dataset.zip
# !ls

# %%
# !unzip dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: negatives/negativePics/nosign09541.png
#   inflating: negatives/negativePics/nosign09542.png
#   inflating: negatives/negativePics/nosign09543.png
#   inflating: negatives/negativePics/nosign09544.png
#   inflating: negatives/negativePics/nosign09545.png
#   inflating: negatives/negativePics/nosign09546.png
#   inflating: negatives/negativePics/nosign09547.png
#   inflating: negatives/negativePics/nosign09548.png
#   inflating: negatives/negativePics/nosign09549.png
#   inflating: negatives/negativePics/nosign09550.png
#   inflating: negatives/negativePics/nosign09551.png
#   inflating: negatives/negativePics/nosign09552.png
#   inflating: negatives/negativePics/nosign09553.png
#   inflating: negatives/negativePics/nosign09554.png
#   inflating: negatives/negativePics/nosign09555.png
#   inflating: negatives/negativePics/nosign09556.png
#   inflating: negatives/negativePics/nosign09557.png
#   inflating: negatives/negativePics/nosign09558.png
#   inflating: negatives/negativePics/nosign09559.png
#   inflating: negatives/negativePics/nosign09560.png
#   inflating: negatives/negativePics/nosign09561.png
#   inflating: negatives/negativePics/nosign09562.png
#   inflating: negatives/negativePics/nosign09563.png
#   inflating: negatives/negativePics/nosign09564.png
#   inflating: negatives/negativePics/nosign09565.png
#   inflating: negatives/negativePics/nosign09566.png
#   inflating: negatives/negativePics/nosign09567.png
#   inflating: negatives/negativePics/nosign09568.png
#   inflating: negatives/negativePics/nosign09569.png
#   inflating: negatives/negativePics/nosign09570.png
#   inflating: negatives/negativePics/nosign09571.png
#   inflating: negatives/negativePics/nosign09572.png
#   inflating: negatives/negativePics/nosign09573.png
#   inflating: negatives/negativePics/nosign09574.png
#   inflating: negatives/negativePics/nosign09575.png
#   inflating: negatives/negativePics/nosign09576.png
#   inflating: negatives/negativePics/nosign09577.png
#   inflating: negatives/negativePics/nosign09578.png
#   inflating: negatives/negativePics/nosign09579.png
#   inflating: negatives/negativePics/nosign09580.png
#   inflating: negatives/negativePics/nosign09581.png
#   inflating: negatives/negativePics/nosign09582.png
#   inflating: negatives/negativePics/nosign09583.png
#   inflating: negatives/negativePics/nosign09584.png
#   inflating: negatives/negativePics/nosign09585.png
#   inflating: negatives/negativePics/nosign09586.png
numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds

print(tf.__version__)

import pathlib
import os.path
from os import path
import sys
print(sys.path)

# dataset_dir = "aiua120214-0/frameAnnotations-DataLog02142012_external_camera"
dataset_dirs = ["aiua120214-0","aiua120214-1","aiua120214-2"]
for dataset_dir in dataset_dirs:

  data_dir = pathlib.Path(dataset_dir).with_suffix('');
  print(data_dir);
  traffic_signs = list(data_dir.glob('*/*.png'));
  # traffic_sign_set=set()
  # print(type(traffic_sign_set))

  # print(data_dir.getFiles());
  print(traffic_signs);

# for traffic_sign in traffic_signs:
#   filename = str(traffic_sign).split("/")[2];
#   sign = filename.split("_", 1);
#   # print(sign);
#   traffic_sign_set.add(sign[0]);

# print(traffic_sign_set);
# Out:
# aiua120214-0	    datasetDescription.pdf  traffic_signs  vid4
# aiua120214-1	    dataset.zip		    vid0	   vid5
# aiua120214-2	    drive		    vid1	   vid6
# aiua120306-0	    negatives		    vid10	   vid7
# aiua120306-1	    readme.txt		    vid11	   vid8
# allAnnotations.csv  sample_data		    vid2	   vid9
# categories.txt	    tools		    vid3	   videoSources.txt
# 2.12.0
# ['/content', '/env/python', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.10/dist-packages/IPython/extensions', '/root/.ipython']
# aiua120214-0
# []
# aiua120214-1
# [PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/stop_1331866061.avi_image18.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/speedLimit_1331865914.avi_image2.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/addedLane_1331865401.avi_image8.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/addedLane_1331865882.avi_image0.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/addedLane_1331865841.avi_image3.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/stop_1331866061.avi_image16.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/signalAhead_1331865987.avi_image1.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/signalAhead_1331865332.avi_image0.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/rampSpeedAdvisory_1331865682.avi_image1.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/laneEnds_1331865727.avi_image6.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/laneEnds_1331865727.avi_image10.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/pedestrianCrossing_1331866041.avi_image10.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/addedLane_1331865690.avi_image8.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/addedLane_1331865882.avi_image22.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/laneEnds_1331865727.avi_image4.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/addedLane_1331865769.avi_image5.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/speedLimit_1331866076.avi_image2.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/curveRight_1331865817.avi_image2.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/thruMergeLeft_1331865938.avi_image2.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/signalAhead_1331865987.avi_image19.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/stop_1331866061.avi_image12.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/signalAhead_1331865987.avi_image14.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/signalAhead_1331865987.avi_image4.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/signalAhead_1331865966.avi_image1.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/pedestrianCrossing_1331866041.avi_image4.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/merge_1331865721.avi_image10.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/signalAhead_1331865966.avi_image6.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/addedLane_1331865401.avi_image7.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/signalAhead_1331865987.avi_image0.png'), PosixPath('aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/rampSpeedAdvisory_1331865676.avi_image0.pn ...
# aiua120214-2
# []

# %%
# ! pwd
# ! ls
# ! mkdir traffic_signs
# ! cd traffic_signs


# for ts in traffic_sign_set:
#   os.mkdir(path+ts)

# ! pwd
# ! ls traffic_signs

# !mv traffic_signs/pedestrianCrossing/* traffic_signs/train/pedestrianCrossing/
# !mv traffic_signs/laneEnds/* traffic_signs/train/laneEnds/
# !mv traffic_signs/stop/* traffic_signs/train/stop/
# !mv traffic_signs/speedLimit/* traffic_signs/train/speedLimit/
# !mv traffic_signs/signalAhead/* traffic_signs/train/signalAhead/

# %%
# print(traffic_signs)
# ! rm -rf traffic_signs
# ! ls traffic_signs/
# ! ls
# ! mkdir traffic_signs


# ts_dict = {};
destination_parent_folder = "traffic_signs/"

ts_set = os.listdir(destination_parent_folder);
print(type(ts_set));
for traffic_sign in traffic_signs:
  src_path = traffic_sign;
  print(traffic_sign);
  destn_filename = str(traffic_sign).split("/")[2];
  sign = destn_filename.split("_")[0];
  destination_sign_folder = destination_parent_folder + sign;
  destn_path = destination_sign_folder + "/" + destn_filename;
  if sign not in ts_set:
     os.mkdir(destination_sign_folder);
     ts_set.append(sign);
  print("src_path:", src_path)   
  print("destn_path:", destn_path)   
  os.replace(src_path, destn_path);




  # print(key);
  # traffic_sign_set.add(key);
  # value = ts_dict.get(key);
  # print(value)
  # directory = path + key;
  # if(value == None):
  #   os.mkdir(directory)
  #   # print(str(traffic_sign));
  #   value = str(traffic_sign);
  #   os.replace(value, directory + sign[2]);
  #   ts_dict[key] = [value];
  #   # print(ts_dict);
  # else:
  #   # value.append(str(traffic_sign));
  #   # dict = {key: value};
  #   # ts_dict.update(dict);
  #   value = str(traffic_sign);
  #   os.replace(value, directory + sign[2]);
  

# print(traffic_sign_set);

# key = "sto2p"

# for k,v in ts_dict.items():
#   print(k);
#   print(v);
#   print("************")
# Out:
# <class 'list'>

# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras
from keras.models import Sequential #keras model architectures
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten,Dropout, BatchNormalization #types of layers
from keras.losses import mean_squared_error, huber, log_cosh  #built-in loss 
from tensorflow.python.keras.saving import hdf5_format  #used for saving models 
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard  #callbacks
from keras.models import model_from_json  #used for loading model architecture from json file

print(tf.__version__)
# Out:
# 2.12.0

# %%
# !mkdir traffic_signs/train
# !mv traffic_signs/* traffic_signs/train/

import pathlib
import os.path
from os import path
import sys
print(sys.path)

# dataset_dir = "aiua120214-0/frameAnnotations-DataLog02142012_external_camera"
dataset_dir = "traffic_signs/train"
data_dir = pathlib.Path(dataset_dir).with_suffix('');
print(data_dir);
traffic_signs = list(data_dir.glob('*/*.png'))
image_count = len(traffic_signs)
print(image_count)
print(path.exists(dataset_dir))
PIL.Image.open(str(traffic_signs[0]))
# Out:
# mkdir: cannot create directory ‘traffic_signs/train’: File exists
# mv: cannot move 'traffic_signs/train' to a subdirectory of itself, 'traffic_signs/train/train'
# ['/content', '/env/python', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.10/dist-packages/IPython/extensions', '/root/.ipython']
# traffic_signs/train
# 961
# True
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x522 at 0x7F03AB4736D0>

# %%
# !ls
# Out:
# aiua120214-0	    datasetDescription.pdf  traffic_signs  vid4
# aiua120214-1	    dataset.zip		    vid0	   vid5
# aiua120214-2	    drive		    vid1	   vid6
# aiua120306-0	    negatives		    vid10	   vid7
# aiua120306-1	    readme.txt		    vid11	   vid8
# allAnnotations.csv  sample_data		    vid2	   vid9
# categories.txt	    tools		    vid3	   videoSources.txt

# %%
batch_size = 32
img_height = 180
img_width = 180

train_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 961 files belonging to 19 classes.
# Using 769 files for training.
# Found 961 files belonging to 19 classes.
# Using 192 files for validation.
# ['.ipynb_checkpoints', 'addedLane', 'curveRight', 'dip', 'keepRight', 'laneEnds', 'leftTurn', 'merge', 'pedestrianCrossing', 'rampSpeedAdvisory', 'rightLaneMustTurn', 'school', 'signalAhead', 'speedLimit', 'stop', 'stopAhead', 'test', 'thruMergeRight', 'truckSpeedLimit']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break

AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

normalization_layer = keras.layers.Rescaling(1./255)

normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# (32, 180, 180, 3)
# (32,)
# 0.0 1.0

# %%
num_classes = len(class_names)

model1 = keras.Sequential([
  keras.layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
  keras.layers.MaxPooling2D(),
  keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
  keras.layers.MaxPooling2D(),
  keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
  keras.layers.MaxPooling2D(),
  keras.layers.Flatten(),
  keras.layers.Dense(128, activation='relu'),
  keras.layers.Dense(num_classes)
])

# %%
model1.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model1.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_15 (Rescaling)    (None, 180, 180, 3)       0
#
#  conv2d_53 (Conv2D)          (None, 180, 180, 16)      448
#
#  max_pooling2d_51 (MaxPoolin  (None, 90, 90, 16)       0
#  g2D)
#
#  conv2d_54 (Conv2D)          (None, 90, 90, 32)        4640
#
#  max_pooling2d_52 (MaxPoolin  (None, 45, 45, 32)       0
#  g2D)
#
#  conv2d_55 (Conv2D)          (None, 45, 45, 64)        18496
#
#  max_pooling2d_53 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  flatten_17 (Flatten)        (None, 30976)             0
#
#  dense_34 (Dense)            (None, 128)               3965056
#
#  dense_35 (Dense)            (None, 19)                2451
#
# =================================================================
# Total params: 3,991,091
# Trainable params: 3,991,091
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model1.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 25/25 [==============================] - 42s 2s/step - loss: 2.7225 - accuracy: 0.2120 - val_loss: 2.2280 - val_accuracy: 0.1927
# Epoch 2/10
# 25/25 [==============================] - 33s 1s/step - loss: 1.8713 - accuracy: 0.3732 - val_loss: 1.3464 - val_accuracy: 0.6094
# Epoch 3/10
# 25/25 [==============================] - 33s 1s/step - loss: 0.7759 - accuracy: 0.7854 - val_loss: 0.5524 - val_accuracy: 0.8594
# Epoch 4/10
# 25/25 [==============================] - 33s 1s/step - loss: 0.2624 - accuracy: 0.9285 - val_loss: 0.3648 - val_accuracy: 0.9167
# Epoch 5/10
# 25/25 [==============================] - 33s 1s/step - loss: 0.0527 - accuracy: 0.9870 - val_loss: 0.3286 - val_accuracy: 0.9219
# Epoch 6/10
# 25/25 [==============================] - 34s 1s/step - loss: 0.0287 - accuracy: 0.9909 - val_loss: 0.3313 - val_accuracy: 0.9271
# Epoch 7/10
# 25/25 [==============================] - 33s 1s/step - loss: 0.0194 - accuracy: 0.9961 - val_loss: 0.2801 - val_accuracy: 0.9375
# Epoch 8/10
# 25/25 [==============================] - 33s 1s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.2515 - val_accuracy: 0.9531
# Epoch 9/10
# 25/25 [==============================] - 32s 1s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2438 - val_accuracy: 0.9479
# Epoch 10/10
# 25/25 [==============================] - 36s 1s/step - loss: 6.8767e-04 - accuracy: 1.0000 - val_loss: 0.2613 - val_accuracy: 0.9479

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# num_classes = len(class_names)

model2 = keras.Sequential([
  keras.layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
  keras.layers.MaxPooling2D(),
  keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
  keras.layers.MaxPooling2D(),
  keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
  keras.layers.MaxPooling2D(),
  keras.layers.Flatten(),
  keras.layers.Dense(128, activation='relu'),
  keras.layers.Dense(num_classes, activation='softmax')
])

model2.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model2.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_18 (Rescaling)    (None, 180, 180, 3)       0
#
#  conv2d_62 (Conv2D)          (None, 180, 180, 16)      448
#
#  max_pooling2d_60 (MaxPoolin  (None, 90, 90, 16)       0
#  g2D)
#
#  conv2d_63 (Conv2D)          (None, 90, 90, 32)        4640
#
#  max_pooling2d_61 (MaxPoolin  (None, 45, 45, 32)       0
#  g2D)
#
#  conv2d_64 (Conv2D)          (None, 45, 45, 64)        18496
#
#  max_pooling2d_62 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  flatten_20 (Flatten)        (None, 30976)             0
#
#  dense_40 (Dense)            (None, 128)               3965056
#
#  dense_41 (Dense)            (None, 19)                2451
#
# =================================================================
# Total params: 3,991,091
# Trainable params: 3,991,091
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model2.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 25/25 [==============================] - 37s 1s/step - loss: 2.6322 - accuracy: 0.1990 - val_loss: 2.2541 - val_accuracy: 0.3438
# Epoch 2/10
# 25/25 [==============================] - 32s 1s/step - loss: 1.9092 - accuracy: 0.3719 - val_loss: 1.5111 - val_accuracy: 0.6510
# Epoch 3/10
# 25/25 [==============================] - 33s 1s/step - loss: 0.9010 - accuracy: 0.7542 - val_loss: 0.6649 - val_accuracy: 0.8229
# Epoch 4/10
# 25/25 [==============================] - 33s 1s/step - loss: 0.3191 - accuracy: 0.9155 - val_loss: 0.3055 - val_accuracy: 0.9271
# Epoch 5/10
# 25/25 [==============================] - 33s 1s/step - loss: 0.0935 - accuracy: 0.9779 - val_loss: 0.2511 - val_accuracy: 0.9219
# Epoch 6/10
# 25/25 [==============================] - 33s 1s/step - loss: 0.0721 - accuracy: 0.9818 - val_loss: 0.3403 - val_accuracy: 0.9271
# Epoch 7/10
# 25/25 [==============================] - 33s 1s/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.2446 - val_accuracy: 0.9479
# Epoch 8/10
# 25/25 [==============================] - 33s 1s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2612 - val_accuracy: 0.9531
# Epoch 9/10
# 25/25 [==============================] - 33s 1s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2536 - val_accuracy: 0.9531
# Epoch 10/10
# 25/25 [==============================] - 33s 1s/step - loss: 8.1385e-04 - accuracy: 1.0000 - val_loss: 0.2717 - val_accuracy: 0.9531

# %%
model3 = keras.Sequential([
  keras.layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  keras.layers.Conv2D(32, 3, padding='valid', activation='relu'),
  keras.layers.MaxPooling2D(),
  keras.layers.Conv2D(64, 3, padding='valid', activation='relu'),
  keras.layers.MaxPooling2D(),
  keras.layers.Conv2D(128, 3, padding='valid', activation='relu'),
  keras.layers.MaxPooling2D(),
  keras.layers.Flatten(),
  keras.layers.Dense(256, activation='relu'),
  keras.layers.Dense(num_classes, activation='softmax')
])

model3.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model3.summary()

epochs=10
history = model3.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_19 (Rescaling)    (None, 180, 180, 3)       0
#
#  conv2d_65 (Conv2D)          (None, 178, 178, 32)      896
#
#  max_pooling2d_63 (MaxPoolin  (None, 89, 89, 32)       0
#  g2D)
#
#  conv2d_66 (Conv2D)          (None, 87, 87, 64)        18496
#
#  max_pooling2d_64 (MaxPoolin  (None, 43, 43, 64)       0
#  g2D)
#
#  conv2d_67 (Conv2D)          (None, 41, 41, 128)       73856
#
#  max_pooling2d_65 (MaxPoolin  (None, 20, 20, 128)      0
#  g2D)
#
#  flatten_21 (Flatten)        (None, 51200)             0
#
#  dense_42 (Dense)            (None, 256)               13107456
#
#  dense_43 (Dense)            (None, 19)                4883
#
# =================================================================
# Total params: 13,205,587
# Trainable params: 13,205,587
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 25/25 [==============================] - 71s 3s/step - loss: 2.3917 - accuracy: 0.2549 - val_loss: 2.0563 - val_accuracy: 0.2448
# Epoch 2/10
# 25/25 [==============================] - 67s 3s/step - loss: 1.2879 - accuracy: 0.5826 - val_loss: 0.5442 - val_accuracy: 0.8542
# Epoch 3/10
# 25/25 [==============================] - 74s 3s/step - loss: 0.2987 - accuracy: 0.9194 - val_loss: 0.3882 - val_accuracy: 0.8906
# Epoch 4/10
# 25/25 [==============================] - 70s 3s/step - loss: 0.0709 - accuracy: 0.9805 - val_loss: 0.2075 - val_accuracy: 0.9583
# Epoch 5/10
# 25/25 [==============================] - 80s 3s/step - loss: 0.0640 - accuracy: 0.9818 - val_loss: 0.2644 - val_accuracy: 0.9427
# Epoch 6/10
# 25/25 [==============================] - 91s 4s/step - loss: 0.0095 - accuracy: 0.9961 - val_loss: 0.2532 - val_accuracy: 0.9427
# Epoch 7/10
# 25/25 [==============================] - 70s 3s/step - loss: 6.1150e-04 - accuracy: 1.0000 - val_loss: 0.2558 - val_accuracy: 0.9531
# Epoch 8/10
# 25/25 [==============================] - 76s 3s/step - loss: 2.4132e-04 - accuracy: 1.0000 - val_loss: 0.2682 - val_accuracy: 0.9531
# Epoch 9/10
# 25/25 [==============================] - 68s 3s/step - loss: 1.7111e-04 - accuracy: 1.0000 - val_loss: 0.2763 - val_accuracy: 0.9531
# Epoch 10/10
# 25/25 [==============================] - 69s 3s/step - loss: 1.3652e-04 - accuracy: 1.0000 - val_loss: 0.2830 - val_accuracy: 0.9531

# %%
def test():
  # test_sign_path = "traffic_signs/test/stop_1330545935.avi_image1.png"
  # test_sign_path = "traffic_signs/test/speedLimit_1331865914.avi_image5.png"
  # test_sign_path = "traffic_signs/test/stop_1331866061.avi_image9.png"

  # test_sign_path ="aiua120214-1/frameAnnotations-DataLog02142012_001_external_camera.avi_annotations/signalAhead_1331866051.avi_image8.png"
  test_sign_path="aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/keepRight_1333393709.avi_image10.png"
  # sunflower_path = tf.keras.utils.get_file('Red_sunflower', origin=sunflower_url)

  test_paths = ["traffic_signs/test/stop_1330545935.avi_image1.png",
                "traffic_signs/test/speedLimit_1331865914.avi_image5.png",
                "traffic_signs/test/stop_1331866061.avi_image9.png",
                "aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/keepRight_1333393709.avi_image10.png"]

  test_dir = "aiua120306-0"
  data_dir = pathlib.Path(test_dir).with_suffix('');
  print(data_dir);
  test_paths = list(data_dir.glob('*/*.png'))
  print(test_paths);

  for test_sign_path in test_paths:
    print("-----", test_sign_path);
    img = keras.utils.load_img(
        test_sign_path, target_size=(img_height, img_width)
    )
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])

    print("This image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 100 * np.max(score))
    )

    print("============ Your Model ==============");

    predictions_1 = your_model.predict(img_array)
    score = tf.nn.softmax(predictions_1[0])

    print("This image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 100 * np.max(score))
    )

    print("============  Model 3 ==============");

    predictions_1 = model3.predict(img_array)
    score = tf.nn.softmax(predictions_1[0])

    print("This image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 100 * np.max(score))
    )

    print("\n\n\n")
# Out:
# aiua120306-0
# [PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/laneEnds_1333394085.avi_image12.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit65_1333391784.avi_image4.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit_1333392825.avi_image3.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388413.avi_image12.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333392856.avi_image24.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333392807.avi_image6.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/curveLeft_1333391702.avi_image0.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/schoolSpeedLimit_1333388518.avi_image8.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/noUTurn_1333393391.avi_image3.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/merge_1333394402.avi_image16.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit35_1333393073.avi_image8.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit_1333392861.avi_image21.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/signalAhead_1333388784.avi_image9.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388556.avi_image1.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/rampSpeedAdvisory35_1333391650.avi_image0.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/keepRight_1333393709.avi_image4.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/addedLane_1333392761.avi_image1.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/thruMergeLeft_1333388544.avi_image4.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/keepRight_1333393709.avi_image10.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388384.avi_image20.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit_1333392825.avi_image0.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/zoneAhead45_1333394398.avi_image2.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333392856.avi_image13.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/noLeftTurn_1333393285.avi_image6.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333392856.avi_image27.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/zoneAhead45_1333394398.avi_image3.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/merge_1333394212.avi_image6.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit_1333388399.avi_image28.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/laneEnds_1333392408.avi_image3.png'), PosixPath('aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388556.avi_image17.png'), PosixPath('aiua120306-0/frameAnnotations-D ...
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/laneEnds_1333394085.avi_image12.png
# 1/1 [==============================] - 0s 40ms/step
# This image most likely belongs to merge with a 90.12 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 76ms/step
# This image most likely belongs to pedestrianCrossing with a 25.17 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 48ms/step
# This image most likely belongs to stop with a 7.59 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit65_1333391784.avi_image4.png
# 1/1 [==============================] - 0s 35ms/step
# This image most likely belongs to signalAhead with a 39.38 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 47ms/step
# This image most likely belongs to .ipynb_checkpoints with a 18.88 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 76ms/step
# This image most likely belongs to keepRight with a 8.40 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit_1333392825.avi_image3.png
# 1/1 [==============================] - 0s 112ms/step
# This image most likely belongs to signalAhead with a 90.52 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 93ms/step
# This image most likely belongs to pedestrianCrossing with a 24.45 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 78ms/step
# This image most likely belongs to speedLimit with a 13.12 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388413.avi_image12.png
# 1/1 [==============================] - 0s 55ms/step
# This image most likely belongs to signalAhead with a 34.48 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 67ms/step
# This image most likely belongs to pedestrianCrossing with a 25.11 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 75ms/step
# This image most likely belongs to stopAhead with a 11.46 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333392856.avi_image24.png
# 1/1 [==============================] - 0s 61ms/step
# This image most likely belongs to speedLimit with a 98.07 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 64ms/step
# This image most likely belongs to pedestrianCrossing with a 25.16 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 78ms/step
# This image most likely belongs to stop with a 13.10 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333392807.avi_image6.png
# 1/1 [==============================] - 0s 61ms/step
# This image most likely belongs to merge with a 54.80 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 59ms/step
# This image most likely belongs to merge with a 19.03 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 83ms/step
# This image most likely belongs to pedestrianCrossing with a 10.64 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/curveLeft_1333391702.avi_image0.png
# 1/1 [==============================] - 0s 81ms/step
# This image most likely belongs to school with a 96.11 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 69ms/step
# This image most likely belongs to leftTurn with a 23.24 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 81ms/step
# This image most likely belongs to laneEnds with a 9.46 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/schoolSpeedLimit_1333388518.avi_image8.png
# 1/1 [==============================] - 0s 69ms/step
# This image most likely belongs to speedLimit with a 99.73 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 63ms/step
# This image most likely belongs to pedestrianCrossing with a 24.90 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 80ms/step
# This image most likely belongs to stop with a 13.12 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/noUTurn_1333393391.avi_image3.png
# 1/1 [==============================] - 0s 63ms/step
# This image most likely belongs to rampSpeedAdvisory with a 74.67 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 53ms/step
# This image most likely belongs to keepRight with a 24.58 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 110ms/step
# This image most likely belongs to rightLaneMustTurn with a 9.44 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/merge_1333394402.avi_image16.png
# 1/1 [==============================] - 0s 68ms/step
# This image most likely belongs to speedLimit with a 97.91 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 71ms/step
# This image most likely belongs to pedestrianCrossing with a 24.99 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 94ms/step
# This image most likely belongs to stop with a 13.12 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit35_1333393073.avi_image8.png
# 1/1 [==============================] - 0s 73ms/step
# This image most likely belongs to speedLimit with a 76.74 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 66ms/step
# This image most likely belongs to pedestrianCrossing with a 25.11 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 76ms/step
# This image most likely belongs to stop with a 11.60 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit_1333392861.avi_image21.png
# 1/1 [==============================] - 0s 60ms/step
# This image most likely belongs to merge with a 80.62 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 70ms/step
# This image most likely belongs to pedestrianCrossing with a 16.36 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 74ms/step
# This image most likely belongs to speedLimit with a 12.88 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/signalAhead_1333388784.avi_image9.png
# 1/1 [==============================] - 0s 70ms/step
# This image most likely belongs to speedLimit with a 96.36 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 72ms/step
# This image most likely belongs to pedestrianCrossing with a 19.84 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 92ms/step
# This image most likely belongs to stop with a 11.99 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388556.avi_image1.png
# 1/1 [==============================] - 0s 36ms/step
# This image most likely belongs to signalAhead with a 81.23 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 43ms/step
# This image most likely belongs to merge with a 18.01 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 60ms/step
# This image most likely belongs to curveRight with a 8.82 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/rampSpeedAdvisory35_1333391650.avi_image0.png
# 1/1 [==============================] - 0s 41ms/step
# This image most likely belongs to school with a 51.99 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 41ms/step
# This image most likely belongs to merge with a 24.95 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 61ms/step
# This image most likely belongs to stop with a 12.49 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/keepRight_1333393709.avi_image4.png
# 1/1 [==============================] - 0s 42ms/step
# This image most likely belongs to speedLimit with a 99.93 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 42ms/step
# This image most likely belongs to pedestrianCrossing with a 25.30 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 50ms/step
# This image most likely belongs to stop with a 13.12 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/addedLane_1333392761.avi_image1.png
# 1/1 [==============================] - 0s 37ms/step
# This image most likely belongs to keepRight with a 60.33 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 47ms/step
# This image most likely belongs to pedestrianCrossing with a 23.87 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 52ms/step
# This image most likely belongs to stop with a 13.06 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/thruMergeLeft_1333388544.avi_image4.png
# 1/1 [==============================] - 0s 50ms/step
# This image most likely belongs to merge with a 97.65 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 51ms/step
# This image most likely belongs to leftTurn with a 22.39 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 56ms/step
# This image most likely belongs to speedLimit with a 12.72 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/keepRight_1333393709.avi_image10.png
# 1/1 [==============================] - 0s 38ms/step
# This image most likely belongs to merge with a 86.09 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 46ms/step
# This image most likely belongs to dip with a 20.69 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 56ms/step
# This image most likely belongs to stop with a 9.09 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388384.avi_image20.png
# 1/1 [==============================] - 0s 42ms/step
# This image most likely belongs to signalAhead with a 99.14 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 42ms/step
# This image most likely belongs to merge with a 21.41 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 53ms/step
# This image most likely belongs to speedLimit with a 13.12 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit_1333392825.avi_image0.png
# 1/1 [==============================] - 0s 41ms/step
# This image most likely belongs to signalAhead with a 99.57 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 58ms/step
# This image most likely belongs to pedestrianCrossing with a 23.67 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 54ms/step
# This image most likely belongs to speedLimit with a 13.12 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/zoneAhead45_1333394398.avi_image2.png
# 1/1 [==============================] - 0s 38ms/step
# This image most likely belongs to signalAhead with a 91.09 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 51ms/step
# This image most likely belongs to merge with a 22.21 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 60ms/step
# This image most likely belongs to stop with a 11.46 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333392856.avi_image13.png
# 1/1 [==============================] - 0s 35ms/step
# This image most likely belongs to signalAhead with a 78.73 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 35ms/step
# This image most likely belongs to pedestrianCrossing with a 18.02 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 57ms/step
# This image most likely belongs to speedLimit with a 13.06 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/noLeftTurn_1333393285.avi_image6.png
# 1/1 [==============================] - 0s 41ms/step
# This image most likely belongs to signalAhead with a 96.86 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 56ms/step
# This image most likely belongs to dip with a 14.93 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 53ms/step
# This image most likely belongs to speedLimit with a 11.95 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333392856.avi_image27.png
# 1/1 [==============================] - 0s 44ms/step
# This image most likely belongs to speedLimit with a 69.28 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 41ms/step
# This image most likely belongs to pedestrianCrossing with a 25.26 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 58ms/step
# This image most likely belongs to stop with a 12.10 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/zoneAhead45_1333394398.avi_image3.png
# 1/1 [==============================] - 0s 35ms/step
# This image most likely belongs to signalAhead with a 61.98 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 45ms/step
# This image most likely belongs to merge with a 22.24 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 56ms/step
# This image most likely belongs to stop with a 12.93 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/merge_1333394212.avi_image6.png
# 1/1 [==============================] - 0s 35ms/step
# This image most likely belongs to school with a 89.93 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 35ms/step
# This image most likely belongs to leftTurn with a 24.01 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 58ms/step
# This image most likely belongs to speedLimit with a 13.08 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit_1333388399.avi_image28.png
# 1/1 [==============================] - 0s 40ms/step
# This image most likely belongs to speedLimit with a 89.07 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 45ms/step
# This image most likely belongs to pedestrianCrossing with a 24.17 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 58ms/step
# This image most likely belongs to speedLimit with a 12.00 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/laneEnds_1333392408.avi_image3.png
# 1/1 [==============================] - 0s 43ms/step
# This image most likely belongs to speedLimit with a 94.97 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 35ms/step
# This image most likely belongs to pedestrianCrossing with a 15.79 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 61ms/step
# This image most likely belongs to stop with a 12.27 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388556.avi_image17.png
# 1/1 [==============================] - 0s 36ms/step
# This image most likely belongs to signalAhead with a 93.39 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 37ms/step
# This image most likely belongs to merge with a 19.40 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 50ms/step
# This image most likely belongs to speedLimit with a 12.60 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/zoneAhead25_1333393809.avi_image2.png
# 1/1 [==============================] - 0s 37ms/step
# This image most likely belongs to signalAhead with a 87.47 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 38ms/step
# This image most likely belongs to pedestrianCrossing with a 25.19 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 59ms/step
# This image most likely belongs to speedLimit with a 13.12 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/addedLane_1333391709.avi_image5.png
# 1/1 [==============================] - 0s 39ms/step
# This image most likely belongs to speedLimit with a 89.38 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 39ms/step
# This image most likely belongs to pedestrianCrossing with a 17.09 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 63ms/step
# This image most likely belongs to stop with a 13.06 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit_1333392825.avi_image1.png
# 1/1 [==============================] - 0s 35ms/step
# This image most likely belongs to signalAhead with a 83.01 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 41ms/step
# This image most likely belongs to pedestrianCrossing with a 17.03 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 50ms/step
# This image most likely belongs to speedLimit with a 13.12 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388712.avi_image15.png
# 1/1 [==============================] - 0s 40ms/step
# This image most likely belongs to signalAhead with a 99.44 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 40ms/step
# This image most likely belongs to dip with a 24.66 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 47ms/step
# This image most likely belongs to speedLimit with a 12.51 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit35_1333393368.avi_image0.png
# 1/1 [==============================] - 0s 41ms/step
# This image most likely belongs to signalAhead with a 71.37 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 42ms/step
# This image most likely belongs to leftTurn with a 17.78 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 57ms/step
# This image most likely belongs to stop with a 12.88 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/merge_1333394402.avi_image13.png
# 1/1 [==============================] - 0s 49ms/step
# This image most likely belongs to stopAhead with a 50.83 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 34ms/step
# This image most likely belongs to pedestrianCrossing with a 20.91 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 55ms/step
# This image most likely belongs to stop with a 13.11 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/rampSpeedAdvisory20_1333392327.avi_image4.png
# 1/1 [==============================] - 0s 38ms/step
# This image most likely belongs to leftTurn with a 60.78 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 40ms/step
# This image most likely belongs to pedestrianCrossing with a 24.35 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 55ms/step
# This image most likely belongs to merge with a 8.22 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit65_1333391784.avi_image2.png
# 1/1 [==============================] - 0s 36ms/step
# This image most likely belongs to signalAhead with a 76.49 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 38ms/step
# This image most likely belongs to .ipynb_checkpoints with a 15.29 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 52ms/step
# This image most likely belongs to speedLimit with a 10.50 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/addedLane_1333393944.avi_image2.png
# 1/1 [==============================] - 0s 34ms/step
# This image most likely belongs to speedLimit with a 95.08 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 35ms/step
# This image most likely belongs to pedestrianCrossing with a 18.57 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 55ms/step
# This image most likely belongs to stop with a 13.08 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388449.avi_image12.png
# 1/1 [==============================] - 0s 69ms/step
# This image most likely belongs to signalAhead with a 64.03 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 71ms/step
# This image most likely belongs to pedestrianCrossing with a 15.46 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 73ms/step
# This image most likely belongs to speedLimit with a 13.11 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/noRightTurn_1333390000.avi_image11.png
# 1/1 [==============================] - 0s 70ms/step
# This image most likely belongs to speedLimit with a 98.78 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 57ms/step
# This image most likely belongs to merge with a 25.16 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 76ms/step
# This image most likely belongs to stop with a 13.11 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333392917.avi_image0.png
# 1/1 [==============================] - 0s 58ms/step
# This image most likely belongs to merge with a 99.00 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 55ms/step
# This image most likely belongs to leftTurn with a 17.16 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 83ms/step
# This image most likely belongs to pedestrianCrossing with a 12.83 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333392917.avi_image1.png
# 1/1 [==============================] - 0s 66ms/step
# This image most likely belongs to merge with a 99.40 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 71ms/step
# This image most likely belongs to dip with a 18.18 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 101ms/step
# This image most likely belongs to pedestrianCrossing with a 13.02 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/schoolSpeedLimit_1333388509.avi_image15.png
# 1/1 [==============================] - 0s 55ms/step
# This image most likely belongs to speedLimit with a 89.41 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 83ms/step
# This image most likely belongs to merge with a 19.54 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 119ms/step
# This image most likely belongs to stop with a 13.11 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/keepRight_1333393709.avi_image14.png
# 1/1 [==============================] - 0s 77ms/step
# This image most likely belongs to merge with a 99.87 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 89ms/step
# This image most likely belongs to dip with a 24.84 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 76ms/step
# This image most likely belongs to pedestrianCrossing with a 12.63 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/keepRight_1333393550.avi_image9.png
# 1/1 [==============================] - 0s 53ms/step
# This image most likely belongs to signalAhead with a 72.45 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 70ms/step
# This image most likely belongs to leftTurn with a 14.98 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 88ms/step
# This image most likely belongs to speedLimit with a 12.50 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333392856.avi_image23.png
# 1/1 [==============================] - 0s 67ms/step
# This image most likely belongs to speedLimit with a 72.88 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 69ms/step
# This image most likely belongs to pedestrianCrossing with a 25.16 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 86ms/step
# This image most likely belongs to stop with a 12.94 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/school_1333388530.avi_image3.png
# 1/1 [==============================] - 0s 57ms/step
# This image most likely belongs to merge with a 91.73 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 57ms/step
# This image most likely belongs to pedestrianCrossing with a 22.08 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 83ms/step
# This image most likely belongs to stop with a 9.98 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/signalAhead_1333389628.avi_image9.png
# 1/1 [==============================] - 0s 66ms/step
# This image most likely belongs to school with a 99.55 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 63ms/step
# This image most likely belongs to leftTurn with a 23.31 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 89ms/step
# This image most likely belongs to signalAhead with a 7.78 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333392856.avi_image8.png
# 1/1 [==============================] - 0s 77ms/step
# This image most likely belongs to signalAhead with a 99.91 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 70ms/step
# This image most likely belongs to pedestrianCrossing with a 20.40 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 75ms/step
# This image most likely belongs to speedLimit with a 13.12 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/yield_1333393949.avi_image2.png
# 1/1 [==============================] - 0s 59ms/step
# This image most likely belongs to speedLimit with a 99.71 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 51ms/step
# This image most likely belongs to pedestrianCrossing with a 24.02 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 50ms/step
# This image most likely belongs to stop with a 13.06 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/merge_1333392341.avi_image9.png
# 1/1 [==============================] - 0s 35ms/step
# This image most likely belongs to pedestrianCrossing with a 53.78 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 43ms/step
# This image most likely belongs to merge with a 17.20 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 58ms/step
# This image most likely belongs to speedLimit with a 12.91 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/signalAhead_1333389632.avi_image0.png
# 1/1 [==============================] - 0s 36ms/step
# This image most likely belongs to school with a 97.46 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 53ms/step
# This image most likely belongs to pedestrianCrossing with a 18.13 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 52ms/step
# This image most likely belongs to speedLimit with a 9.81 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit_1333392910.avi_image7.png
# 1/1 [==============================] - 0s 37ms/step
# This image most likely belongs to merge with a 91.88 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 38ms/step
# This image most likely belongs to merge with a 17.48 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 50ms/step
# This image most likely belongs to speedLimit with a 12.50 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/pedestrianCrossing_1333389971.avi_image18.png
# 1/1 [==============================] - 0s 39ms/step
# This image most likely belongs to school with a 51.45 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 36ms/step
# This image most likely belongs to merge with a 23.87 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 57ms/step
# This image most likely belongs to speedLimit with a 9.16 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/pedestrianCrossing_1333389971.avi_image13.png
# 1/1 [==============================] - 0s 38ms/step
# This image most likely belongs to signalAhead with a 57.91 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 46ms/step
# This image most likely belongs to dip with a 22.98 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 51ms/step
# This image most likely belongs to stop with a 8.22 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit_1333393715.avi_image4.png
# 1/1 [==============================] - 0s 36ms/step
# This image most likely belongs to school with a 76.92 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 43ms/step
# This image most likely belongs to leftTurn with a 16.94 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 55ms/step
# This image most likely belongs to signalAhead with a 8.22 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/merge_1333392630.avi_image0.png
# 1/1 [==============================] - 0s 35ms/step
# This image most likely belongs to signalAhead with a 99.83 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 38ms/step
# This image most likely belongs to .ipynb_checkpoints with a 13.54 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 68ms/step
# This image most likely belongs to speedLimit with a 13.12 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/zoneAhead25_1333393809.avi_image10.png
# 1/1 [==============================] - 0s 36ms/step
# This image most likely belongs to speedLimit with a 70.60 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 38ms/step
# This image most likely belongs to pedestrianCrossing with a 25.36 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 53ms/step
# This image most likely belongs to stop with a 10.26 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/pedestrianCrossing_1333389986.avi_image18.png
# 1/1 [==============================] - 0s 43ms/step
# This image most likely belongs to signalAhead with a 98.87 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 38ms/step
# This image most likely belongs to merge with a 15.48 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 54ms/step
# This image most likely belongs to speedLimit with a 13.12 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388449.avi_image15.png
# 1/1 [==============================] - 0s 40ms/step
# This image most likely belongs to signalAhead with a 90.69 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 60ms/step
# This image most likely belongs to merge with a 24.00 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 54ms/step
# This image most likely belongs to speedLimit with a 13.07 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388413.avi_image2.png
# 1/1 [==============================] - 0s 37ms/step
# This image most likely belongs to stop with a 93.06 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 36ms/step
# This image most likely belongs to pedestrianCrossing with a 22.73 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 53ms/step
# This image most likely belongs to stop with a 12.08 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388449.avi_image25.png
# 1/1 [==============================] - 0s 38ms/step
# This image most likely belongs to signalAhead with a 52.70 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 37ms/step
# This image most likely belongs to merge with a 23.66 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 56ms/step
# This image most likely belongs to speedLimit with a 13.03 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/keepRight_1333393538.avi_image3.png
# 1/1 [==============================] - 0s 35ms/step
# This image most likely belongs to signalAhead with a 47.09 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 38ms/step
# This image most likely belongs to merge with a 16.66 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 55ms/step
# This image most likely belongs to stop with a 12.16 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/noRightTurn_1333390000.avi_image2.png
# 1/1 [==============================] - 0s 35ms/step
# This image most likely belongs to speedLimit with a 61.83 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 42ms/step
# This image most likely belongs to merge with a 25.08 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 51ms/step
# This image most likely belongs to speedLimit with a 11.84 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/signalAhead_1333389628.avi_image4.png
# 1/1 [==============================] - 0s 42ms/step
# This image most likely belongs to school with a 99.92 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 37ms/step
# This image most likely belongs to leftTurn with a 25.24 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 54ms/step
# This image most likely belongs to signalAhead with a 7.80 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333392856.avi_image5.png
# 1/1 [==============================] - 0s 37ms/step
# This image most likely belongs to signalAhead with a 97.44 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 36ms/step
# This image most likely belongs to pedestrianCrossing with a 15.44 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 46ms/step
# This image most likely belongs to speedLimit with a 13.12 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/truckSpeedLimit55_1333394302.avi_image4.png
# 1/1 [==============================] - 0s 37ms/step
# This image most likely belongs to merge with a 93.66 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 44ms/step
# This image most likely belongs to dip with a 16.91 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 61ms/step
# This image most likely belongs to pedestrianCrossing with a 9.78 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388413.avi_image3.png
# 1/1 [==============================] - 0s 44ms/step
# This image most likely belongs to stop with a 58.50 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 40ms/step
# This image most likely belongs to pedestrianCrossing with a 23.12 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 56ms/step
# This image most likely belongs to stop with a 13.02 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/rampSpeedAdvisory20_1333392327.avi_image6.png
# 1/1 [==============================] - 0s 39ms/step
# This image most likely belongs to leftTurn with a 30.03 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 43ms/step
# This image most likely belongs to pedestrianCrossing with a 25.28 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 66ms/step
# This image most likely belongs to addedLane with a 8.07 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit45_1333393955.avi_image8.png
# 1/1 [==============================] - 0s 36ms/step
# This image most likely belongs to speedLimit with a 99.54 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 50ms/step
# This image most likely belongs to pedestrianCrossing with a 22.10 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 52ms/step
# This image most likely belongs to stop with a 13.12 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/pedestrianCrossing_1333389986.avi_image22.png
# 1/1 [==============================] - 0s 36ms/step
# This image most likely belongs to speedLimit with a 62.39 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 46ms/step
# This image most likely belongs to dip with a 14.87 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 61ms/step
# This image most likely belongs to speedLimit with a 9.52 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit35_1333393073.avi_image6.png
# 1/1 [==============================] - 0s 35ms/step
# This image most likely belongs to merge with a 52.53 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 34ms/step
# This image most likely belongs to pedestrianCrossing with a 24.94 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 55ms/step
# This image most likely belongs to stop with a 10.97 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit_1333388399.avi_image2.png
# 1/1 [==============================] - 0s 36ms/step
# This image most likely belongs to merge with a 85.00 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 43ms/step
# This image most likely belongs to merge with a 19.97 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 48ms/step
# This image most likely belongs to speedLimit with a 12.50 percent confidence.
#
#
#
#
# ...
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 71ms/step
# This image most likely belongs to stop with a 13.12 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388384.avi_image10.png
# 1/1 [==============================] - 0s 47ms/step
# This image most likely belongs to school with a 90.17 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 49ms/step
# This image most likely belongs to merge with a 18.91 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 64ms/step
# This image most likely belongs to signalAhead with a 12.15 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/signalAhead_1333392024.avi_image0.png
# 1/1 [==============================] - 0s 41ms/step
# This image most likely belongs to addedLane with a 58.29 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 49ms/step
# This image most likely belongs to merge with a 22.30 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 88ms/step
# This image most likely belongs to merge with a 8.85 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/noUTurn_1333393391.avi_image4.png
# 1/1 [==============================] - 0s 47ms/step
# This image most likely belongs to speedLimit with a 73.51 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 56ms/step
# This image most likely belongs to keepRight with a 23.59 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 74ms/step
# This image most likely belongs to stop with a 12.93 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit25_1333392931.avi_image2.png
# 1/1 [==============================] - 0s 56ms/step
# This image most likely belongs to signalAhead with a 93.22 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 52ms/step
# This image most likely belongs to dip with a 18.55 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 80ms/step
# This image most likely belongs to speedLimit with a 10.23 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit_1333388399.avi_image18.png
# 1/1 [==============================] - 0s 45ms/step
# This image most likely belongs to merge with a 58.60 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 57ms/step
# This image most likely belongs to dip with a 15.99 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 77ms/step
# This image most likely belongs to speedLimit with a 10.12 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388746.avi_image14.png
# 1/1 [==============================] - 0s 33ms/step
# This image most likely belongs to speedLimit with a 85.75 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 49ms/step
# This image most likely belongs to merge with a 24.54 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 76ms/step
# This image most likely belongs to stop with a 12.99 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit_1333388399.avi_image3.png
# 1/1 [==============================] - 0s 37ms/step
# This image most likely belongs to signalAhead with a 50.51 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 49ms/step
# This image most likely belongs to merge with a 20.97 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 79ms/step
# This image most likely belongs to speedLimit with a 12.11 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/merge_1333390051.avi_image3.png
# 1/1 [==============================] - 0s 37ms/step
# This image most likely belongs to merge with a 99.14 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 35ms/step
# This image most likely belongs to pedestrianCrossing with a 14.78 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 66ms/step
# This image most likely belongs to pedestrianCrossing with a 10.41 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/speedLimit_1333392861.avi_image0.png
# 1/1 [==============================] - 0s 41ms/step
# This image most likely belongs to speedLimit with a 48.08 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 52ms/step
# This image most likely belongs to pedestrianCrossing with a 22.03 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 100ms/step
# This image most likely belongs to stop with a 9.22 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/addedLane_1333391709.avi_image11.png
# 1/1 [==============================] - 0s 52ms/step
# This image most likely belongs to signalAhead with a 73.44 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 50ms/step
# This image most likely belongs to pedestrianCrossing with a 19.52 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 82ms/step
# This image most likely belongs to stopAhead with a 11.64 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388449.avi_image8.png
# 1/1 [==============================] - 0s 38ms/step
# This image most likely belongs to keepRight with a 69.78 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 56ms/step
# This image most likely belongs to pedestrianCrossing with a 19.91 percent confidence.
# ============  Model 3 ==============
# 1/1 [==============================] - 0s 62ms/step
# This image most likely belongs to speedLimit with a 13.04 percent confidence.
#
#
#
#
# ----- aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/stop_1333388746.avi_image2.png
# 1/1 [==============================] - 0s 37ms/step
# This image most likely belongs to merge with a 51.78 percent confidence.
# ============ Your Model ==============
# 1/1 [==============================] - 0s 72ms/step
# This image most likely belongs to merge with a 19.72 percent confidence.
# ============  Model 3 ==============
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2697       with c_api_util.tf_buffer() as buf:
# -> 2698         pywrap_tf_session.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2699         data = pywrap_tf_session.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'Slice_1' has no attr named '_read_only_resource_inputs'.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/auto_control_deps_utils.py in get_read_write_resource_inputs(op)
#     104   try:
# --> 105     read_only_input_indices = op.get_attr(READ_ONLY_RESOURCE_INPUTS_ATTR)
#     106   except ValueError:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2701       # Convert to ValueError for backwards compatibility.
# -> 2702       raise ValueError(e.message)
#    2703     x = attr_value_pb2.AttrValue()
#
# ValueError: Operation 'Slice_1' has no attr named '_read_only_resource_inputs'.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-ab28b07ad56d> in <cell line: 20>()
#      42   print("============  Model 3 ==============");
#      43
# ---> 44   predictions_1 = model3.predict(img_array)
#      45   score = tf.nn.softmax(predictions_1[0])
#      46
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2347                     )
#    2348
# -> 2349             data_handler = data_adapter.get_data_handler(
#    2350                 x=x,
#    2351                 batch_size=batch_size,
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1581     if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1582         return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1583     return DataHandler(*args, **kwargs)
#    1584
#    1585
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1258
#    1259         adapter_cls = select_data_adapter(x, y)
# -> 1260         self._adapter = adapter_cls(
#    1261             x,
#    1262             y,
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     344             return flat_dataset
#     345
# --> 346         indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     347
#     348         dataset = self.slice_inputs(indices_dataset, inputs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/dataset_ops.py in flat_map(self, map_func, name)
#    2283     # pylint: disable=g-import-not-at-top,protected-access
#    2284     from tensorflow.python.data.ops import flat_map_op
# -> 2285     return flat_map_op._flat_map(self, map_func, name=name)
#    2286     # pylint: enable=g-import-not-at-top,protected-access
#    2287
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/flat_map_op.py in _flat_map(input_dataset, map_func, name)
#      22 def _flat_map(input_dataset, map_func, name=None):  # pylint: disable=unused-private-name
#      23   """See `Dataset.flat_map()` for details."""
# ---> 24   return _FlatMapDataset(input_dataset, map_func, name)
#      25
#      26
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/flat_map_op.py in __init__(self, input_dataset, map_func, name)
#      31
#      32     self._input_dataset = input_dataset
# ---> 33     self._map_func = structured_function.StructuredFunctionWrapper(
#      34         map_func, self._transformation_name(), dataset=input_dataset)
#      35     if not isinstance(self._map_func.output_structure, dataset_ops.DatasetSpec):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     259         fn_factory = trace_tf_function(defun_kwargs)
#     260
# --> 261     self._function = fn_factory()
#     262     # There is no graph to add in eager mode.
#     263     add_to_graph &= not context.executing_eagerly()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in get_concrete_function(self, *args, **kwargs)
#     230         `tf.Tensor` or `tf.TensorSpec`.
#     231     """
# --> 232     concrete_function = self._get_concrete_function_garbage_collected(
#     233         *args, **kwargs)
#     234     concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#     200
#     201     with self._lock:
# --> 202       concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     203       seen_names = set()
#     204       concrete_function._arg_keywords = []  # pylint: disable=protected-access
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in _maybe_define_concrete_function(self, args, kwargs)
#     164       kwargs = {}
#     165
# --> 166     return self._maybe_define_function(args, kwargs)
#     167
#     168   def _get_concrete_function_internal_garbage_collected(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in _maybe_define_function(self, args, kwargs)
#     394           kwargs = placeholder_bound_args.kwargs
#     395
# --> 396           concrete_function = self._create_concrete_function(
#     397               args, kwargs, func_graph)
#     398
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in _create_concrete_function(self, args, kwargs, func_graph)
#     298
#     299     concrete_function = monomorphic_function.ConcreteFunction(
# --> 300         func_graph_module.func_graph_from_py_func(
#     301             self._name,
#     302             self._python_function,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders, acd_record_initial_resource_uses)
#    1111     deps_control_manager = ops.NullContextmanager()
#    1112
# -> 1113   with func_graph.as_default(), deps_control_manager as deps_ctx:
#    1114     current_scope = variable_scope.get_variable_scope()
#    1115     default_use_resource = current_scope.use_resource
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/auto_control_deps.py in __exit__(self, unused_type, unused_value, unused_traceback)
#     463       # Check for any resource inputs. If we find any, we update control_inputs
#     464       # and last_write_to_resource.
# --> 465       for inp, resource_type in _get_resource_inputs(op):
#     466         is_read = resource_type == ResourceType.READ_ONLY
#     467         input_id = ops.tensor_id(inp)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/auto_control_deps.py in _get_resource_inputs(op)
#     661 def _get_resource_inputs(op):
#     662   """Returns an iterable of resources touched by this `op`."""
# --> 663   reads, writes = utils.get_read_write_resource_inputs(op)
#     664   saturated = False
#     665   while not saturated:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/auto_control_deps_utils.py in get_read_write_resource_inputs(op)
#     103
#     104   try:
# --> 105     read_only_input_indices = op.get_attr(READ_ONLY_RESOURCE_INPUTS_ATTR)
#     106   except ValueError:
#     107     # Attr was not set. Add all resource inputs to `writes` and return.
#
# KeyboardInterrupt:
